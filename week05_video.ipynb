# %% [markdown]
# # Week 5 - Plotting with `matplotlib`
#
# Charlotte Desvages

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.8.1-cp311-cp311-win_amd64.whl (7.6 MB)
#                                               0.0/7.6 MB ? eta -:--:--
#      -                                        0.2/7.6 MB 7.3 MB/s eta 0:00:02
#      --                                       0.5/7.6 MB 6.4 MB/s eta 0:00:02
#      -----                                    1.1/7.6 MB 8.8 MB/s eta 0:00:01
#      -------                                  1.5/7.6 MB 8.6 MB/s eta 0:00:01
#      ----------                               2.1/7.6 MB 10.2 MB/s eta 0:00:01
#      -------------                            2.5/7.6 MB 10.7 MB/s eta 0:00:01
#      -----------------                        3.3/7.6 MB 11.0 MB/s eta 0:00:01
#      --------------------                     3.9/7.6 MB 11.3 MB/s eta 0:00:01
#      -----------------------                  4.4/7.6 MB 11.8 MB/s eta 0:00:01
#      --------------------------               5.0/7.6 MB 11.4 MB/s eta 0:00:01
#      ------------------------------           5.8/7.6 MB 12.4 MB/s eta 0:00:01
#      ----------------------------------       6.7/7.6 MB 12.9 MB/s eta 0:00:01
#      ---------------------------------------  7.6/7.6 MB 13.6 MB/s eta 0:00:01
#      ---------------------------------------- 7.6/7.6 MB 13.2 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.0-cp311-cp311-win_amd64.whl (187 kB)
#                                               0.0/187.6 kB ? eta -:--:--
#      ---------------------------------------- 187.6/187.6 kB ? eta 0:00:00
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.44.0-cp311-cp311-win_amd64.whl (2.1 MB)
#                                               0.0/2.1 MB ? eta -:--:--
#      --------------------                     1.1/2.1 MB 34.4 MB/s eta 0:00:01
#      ---------------------------------------  2.1/2.1 MB 26.9 MB/s eta 0:00:01
#      ---------------------------------------- 2.1/2.1 MB 22.7 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
#                                               0.0/56.1 kB ? eta -:--:--
#      ---------------------------------------- 56.1/56.1 kB 2.9 MB/s eta 0:00:00
# Collecting numpy<2,>=1.21 (from matplotlib)
#   Downloading numpy-1.26.2-cp311-cp311-win_amd64.whl (15.8 MB)
#                                               0.0/15.8 MB ? eta -:--:--
#      --                                       1.1/15.8 MB 34.4 MB/s eta 0:00:01
#      ----                                     1.6/15.8 MB 26.4 MB/s eta 0:00:01
#      -----                                    2.2/15.8 MB 19.7 MB/s eta 0:00:01
#      ------                                   2.7/15.8 MB 17.1 MB/s eta 0:00:01
#      --------                                 3.4/15.8 MB 16.7 MB/s eta 0:00:01
#      ---------                                3.9/15.8 MB 17.9 MB/s eta 0:00:01
#      -----------                              4.6/15.8 MB 16.4 MB/s eta 0:00:01
#      --------------                           5.6/15.8 MB 17.8 MB/s eta 0:00:01
#      ----------------                         6.6/15.8 MB 18.5 MB/s eta 0:00:01
#      ------------------                       7.3/15.8 MB 18.0 MB/s eta 0:00:01
#      --------------------                     8.2/15.8 MB 18.8 MB/s eta 0:00:01
#      ----------------------                   8.8/15.8 MB 18.9 MB/s eta 0:00:01
#      ------------------------                10.0/15.8 MB 18.9 MB/s eta 0:00:01
#      ---------------------------             11.3/15.8 MB 18.7 MB/s eta 0:00:01
#      ------------------------------          12.3/15.8 MB 19.8 MB/s eta 0:00:01
#      --------------------------------        13.1/15.8 MB 20.5 MB/s eta 0:00:01
#      ----------------------------------      13.9/15.8 MB 20.5 MB/s eta 0:00:01
#      ------------------------------------    14.9/15.8 MB 21.8 MB/s eta 0:00:01
#      --------------------------------------  15.6/15.8 MB 21.1 MB/s eta 0:00:01
#      --------------------------------------  15.8/15.8 MB 21.1 MB/s eta 0:00:01
#      --------------------------------------  15.8/15.8 MB 21.1 MB/s eta 0:00:01
#      --------------------------------------- 15.8/15.8 MB 18.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\filos\appdata\roaming\python\python311\site-packages (from matplotlib) (23.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading Pillow-10.1.0-cp311-cp311-win_amd64.whl (2.6 MB)
#                                               0.0/2.6 MB ? eta -:--:--
#      -----------                              0.8/2.6 MB 16.3 MB/s eta 0:00:01
#      ---------------------------              1.8/2.6 MB 22.4 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 MB 20.7 MB/s eta 0:00:01
#      ---------------------------------------- 2.6/2.6 MB 15.2 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#                                               0.0/103.1 kB ? eta -:--:--
#      -------------------------------------- 103.1/103.1 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\filos\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\filos\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.44.0 kiwisolver-1.4.5 matplotlib-3.8.1 numpy-1.26.2 pillow-10.1.0 pyparsing-3.1.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'c:\Users\filos\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\filos\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [1, 3, 4, 2]

plt.plot(x, y)
plt.show()

# %%
fig, ax = plt.subplots(2,2)
ax[1,0].plot(x,y)
plt.show()

# %%
import numpy as np

x = np.linspace(-2*np.pi, 2*np.pi, 100)
y = np.cos(x)

fig, ax = plt.subplots()
ax.plot(x, y, 'r+')
plt.show()

# %% [markdown]
# ## Figures and Axes
#
# Instead of using `plt.plot()`, we can have more control over *where* we plot something by first creating a `Figure` and one or more `Axes`.

# %%
fig, ax = plt.subplots(1, 3)
ax[2].plot(x, y)
plt.show()

# %% [markdown]
# ## Customising plots
#
# Consult [the documentation](https://matplotlib.org/contents.html)! Useful resources are the Examples Gallery and the Tutorials.

# %%
import numpy as np
np.random.seed(19680801)
import matplotlib.pyplot as plt


fig, ax = plt.subplots()
for color in ['tab:blue', 'tab:orange', 'tab:green']:
    n = 750
    x, y = np.random.rand(2, n)
    scale = 200.0 * np.random.rand(n)
    ax.scatter(x, y, c=color, s=scale, label=color,
               alpha=0.3, edgecolors='none')

ax.legend()
ax.grid(False)

plt.show()

# %% [markdown]
# This is an example from the tutorial video .

# %%
import numpy as np
x = np.linspace(-2*np.pi,2*np.pi, 100)
y = np.cos(x)

fig, ax = plt.subplots()
ax.plot(x, y, 'b+')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
